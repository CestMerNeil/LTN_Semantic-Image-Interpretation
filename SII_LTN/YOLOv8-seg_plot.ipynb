# %%
from ultralytics import YOLO
import ultralytics
from plot_seg_img import plot_seg
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.101 🚀 Python-3.8.19 torch-2.4.1 CPU (Apple M2 Pro)
# Setup complete ✅ (10 CPUs, 16.0 GB RAM, 265.8/460.4 GB disk)

# %%
model = YOLO('pretrainModels/yolov8x-seg.pt')
image = "data/VCG41N649207386.jpg"
results = model(image)
plot_seg(results, True, False, alpha=0.5)
#print(results[0].names)
# Out:
# image 1/1 /Users/neil/Code/LTNtorch/SII_LTN/data/VCG41N649207386.jpg: 448x640 4 persons, 314.6ms
# Speed: 1.4ms preprocess, 314.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
